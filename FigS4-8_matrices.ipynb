# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import itertools

# %%
dimensions_list = ['grade','race','sex']
num_dimensions = len(dimensions_list)
sex_list = ["Female","Male"]
race_list = ["White","Black","Hispanic","Asian","Mixed/other"]
grade_list = ["7th","8th","9th","10th","11th","12th"]
all_attributes_dict = {
    "grade":grade_list,
    "race":race_list,
    "sex":sex_list
}

multidim_groups = list(itertools.product(*[all_attributes_dict[d] for d in dimensions_list]))

results_df = pd.read_csv("preference_results_v4_merged.csv")

# %%
## https://stackoverflow.com/questions/47391948/pandas-style-background-gradient-using-other-dataframe
def b_g(s, df_ref, cmap='viridis', vmin=0, vmax=1):
    # Pass the columns from Dataframe A 
    a = df_ref.loc[:,s.name].copy()
    norm = colors.Normalize(vmin,vmax)
    normed = norm(a.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]

    return ['background-color: %s' % color for color in c]

def font_color(s, df_ref, cmap='viridis', vmin=0,vmax=1):
    # Pass the columns from Dataframe A 
    a = df_ref.loc[:,s.name].copy()
    norm = colors.Normalize(vmin,vmax)
    normed = norm(a.values)
    c2 = ["#ffffff" if colors.rgb_to_hsv(x[:-1])[-1]<0.7 else "#000000" for x in plt.cm.get_cmap(cmap)(normed) ]
    
    return ['color: %s' % color for color in c2]

# %%
## Select school
school = 61
resutls_df_school = results_df[results_df.school == school]

# %% [markdown]
# ## Race

# %%
## Race
pvals_dfs = {}
h_dfs = {}
h_norm_dfs = {}
for i, gi in enumerate(race_list):
    for j, gj in enumerate(race_list):
        if gi == gj:
            continue
        col = "MRQAP_pval1s_h_and_1d-simple_race_" + gi + "-" + gj
        vals = resutls_df_school[col].values
        assert len(vals)==1
        vals = vals[0]
        if np.isnan(vals):
            if np.isnan(resutls_df_school["MRQAP_pval2s_h_and_1d-simple_race_" + gj + "-" + gi].values[0]):
                continue
            else:
                print ("We have a problem in", gi,gj)
        if gi not in pvals_dfs:
            pvals_dfs[gi] = {}
            h_norm_dfs[gi] = {}
        pvals_dfs[gi][gj] = vals
        h_norm_dfs[gi][gj] = resutls_df_school["h_norm_and_1d-simple_race_" + gi + "-" + gj].values[0]
t1 = pd.DataFrame.from_dict(h_norm_dfs,orient="index")
t2 = pd.DataFrame.from_dict(pvals_dfs,orient="index")
# t1.style.apply(lambda x: t2.applymap(color_cells), axis=None)
## https://stackoverflow.com/questions/25571882/pandas-columns-correlation-with-statistical-significance
p = t2.applymap(lambda x: ''.join(['*' for t in [.05, .01, .001] if x<=t]))
t1.round(2).astype(str) + p
t1str = t1.round(2).astype(str) + p
t1str[t1str=="nan"] = "-"
t1str = t1str[[i for i in race_list if i in h_norm_dfs]]
t1str = t1str.loc[[i for i in race_list if i in h_norm_dfs]]
## https://stackoverflow.com/questions/55929264/using-a-dataframe-to-format-the-style-of-another-dataframe
t1str_style = t1str.style.format(na_rep='-').set_properties(**{'text-align': 'center'}).applymap_index(lambda v: "font-weight: bold;", axis="index").applymap_index(lambda v: "font-weight: bold;", axis="columns")

t1 = t1[[i for i in race_list if i in h_norm_dfs]]
t1 = t1.loc[[i for i in race_list if i in h_norm_dfs]]
styled_result = t1str.style.apply(lambda x: b_g(x,t1,vmin=0,vmax=1)).apply(lambda x: font_color(x,t1)).set_properties(**{'text-align': 'center'}).applymap_index(lambda v: "font-weight: bold;", axis="index").applymap_index(lambda v: "font-weight: bold;", axis="columns")
styled_result
# Out:
# C:\Users\csh_samu\AppData\Local\Temp\ipykernel_8\1550239438.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
# C:\Users\csh_samu\AppData\Local\Temp\ipykernel_8\1550239438.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c2 = ["#ffffff" if colors.rgb_to_hsv(x[:-1])[-1]<0.7 else "#000000" for x in plt.cm.get_cmap(cmap)(normed) ]
# <style type="text/css">
# #T_2d8fa_row0_col0, #T_2d8fa_row1_col1, #T_2d8fa_row2_col2, #T_2d8fa_row3_col3, #T_2d8fa_row4_col4 {
#   background-color: #000000;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row0_col1 {
#   background-color: #482071;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row0_col2 {
#   background-color: #34618d;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row0_col3, #T_2d8fa_row1_col0 {
#   background-color: #482576;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row0_col4 {
#   background-color: #2f6c8e;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row1_col2 {
#   background-color: #404588;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row1_col3 {
#   background-color: #481d6f;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row1_col4 {
#   background-color: #69cd5b;
#   color: #000000;
#   text-align: center;
# }
# #T_2d8fa_row2_col0 {
#   background-color: #21908d;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row2_col1 {
#   background-color: #433e85;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row2_col3 {
#   background-color: #424086;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row2_col4 {
#   background-color: #2e6f8e;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row3_col0 {
#   background-color: #470d60;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row3_col1 {
#   background-color: #471164;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row3_col2 {
#   background-color: #482173;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row3_col4 {
#   background-color: #33638d;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row4_col0 {
#   background-color: #fde725;
#   color: #000000;
#   text-align: center;
# }
# #T_2d8fa_row4_col1 {
#   background-color: #dfe318;
#   color: #000000;
#   text-align: center;
# }
# #T_2d8fa_row4_col2 {
#   background-color: #26818e;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_row4_col3 {
#   background-color: #26ad81;
#   color: #ffffff;
#   text-align: center;
# }
# #T_2d8fa_level0_row0, #T_2d8fa_level0_row1, #T_2d8fa_level0_row2, #T_2d8fa_level0_row3, #T_2d8fa_level0_row4 {
#   font-weight: bold;
# }
# #T_2d8fa_level0_col0, #T_2d8fa_level0_col1, #T_2d8fa_level0_col2, #T_2d8fa_level0_col3, #T_2d8fa_level0_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_2d8fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d8fa_level0_col0" class="col_heading level0 col0" >White</th>
#       <th id="T_2d8fa_level0_col1" class="col_heading level0 col1" >Black</th>
#       <th id="T_2d8fa_level0_col2" class="col_heading level0 col2" >Hispanic</th>
#       <th id="T_2d8fa_level0_col3" class="col_heading level0 col3" >Asian</th>
#       <th id="T_2d8fa_level0_col4" class="col_heading level0 col4" >Mixed/other</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d8fa_level0_row0" class="row_heading level0 row0" >White</th>
#       <td id="T_2d8fa_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_2d8fa_row0_col1" class="data row0 col1" >0.09***</td>
#       <td id="T_2d8fa_row0_col2" class="data row0 col2" >0.31***</td>
#       <td id="T_2d8fa_row0_col3" class="data row0 col3" >0.1***</td>
#       <td id="T_2d8fa_row0_col4" class="data row0 col4" >0.35*</td>
#     </tr>
#     <tr>
#       <th id="T_2d8fa_level0_row1" class="row_heading level0 row1" >Black</th>
#       <td id="T_2d8fa_row1_col0" class="data row1 col0" >0.1***</td>
#       <td id="T_2d8fa_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_2d8fa_row1_col2" class="data row1 col2" >0.21***</td>
#       <td id="T_2d8fa_row1_col3" class="data row1 col3" >0.08***</td>
#       <td id="T_2d8fa_row1_col4" class="data row1 col4" >0.77*</td>
#     </tr>
#     <tr>
#       <th id="T_2d8fa_level0_row2" class="row_heading level0 row2" >Hispanic</th>
#       <td id="T_2d8fa_row2_col0" class="data row2 col0" >0.5***</td>
#       <td id="T_2d8fa_row2_col1" class="data row2 col1" >0.18***</td>
#       <td id="T_2d8fa_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_2d8fa_row2_col3" class="data row2 col3" >0.19***</td>
#       <td id="T_2d8fa_row2_col4" class="data row2 col4" >0.36***</td>
#     </tr>
#     <tr>
#       <th id="T_2d8fa_level0_row3" class="row_heading level0 row3" >Asian</th>
#       <td id="T_2d8fa_row3_col0" class="data row3 col0" >0.03***</td>
#       <td id="T_2d8fa_row3_col1" class="data row3 col1" >0.05***</td>
#       <td id="T_2d8fa_row3_col2" class="data row3 col2" >0.09***</td>
#       <td id="T_2d8fa_row3_col3" class="data row3 col3" >-</td>
#       <td id="T_2d8fa_row3_col4" class="data row3 col4" >0.31***</td>
#     </tr>
#     <tr>
#       <th id="T_2d8fa_level0_row4" class="row_heading level0 row4" >Mixed/other</th>
#       <td id="T_2d8fa_row4_col0" class="data row4 col0" >1.27</td>
#       <td id="T_2d8fa_row4_col1" class="data row4 col1" >0.95</td>
#       <td id="T_2d8fa_row4_col2" class="data row4 col2" >0.44***</td>
#       <td id="T_2d8fa_row4_col3" class="data row4 col3" >0.62**</td>
#       <td id="T_2d8fa_row4_col4" class="data row4 col4" >-</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Grade

# %%
## Grade
pvals_dfs = {}
h_dfs = {}
h_norm_dfs = {}
for i, gi in enumerate(grade_list):
    for j, gj in enumerate(grade_list):
        if gi == gj:
            continue
        col = "MRQAP_pval1s_h_and_1d-simple_grade_" + gi + "-" + gj
        vals = resutls_df_school[col].values
        assert len(vals)==1
        vals = vals[0]
        if np.isnan(vals):
            if np.isnan(resutls_df_school["MRQAP_pval2s_h_and_1d-simple_grade_" + gj + "-" + gi].values[0]):
                continue
            else:
                print ("We have a problem in", gi,gj)
        if gi not in pvals_dfs:
            pvals_dfs[gi] = {}
            h_norm_dfs[gi] = {}
        pvals_dfs[gi][gj] = vals
        h_norm_dfs[gi][gj] = resutls_df_school["h_norm_and_1d-simple_grade_" + gi + "-" + gj].values[0]
print (h_norm_dfs)
t1 = pd.DataFrame.from_dict(h_norm_dfs,orient="index")
t2 = pd.DataFrame.from_dict(pvals_dfs,orient="index")
# t1.style.apply(lambda x: t2.applymap(color_cells), axis=None)
## https://stackoverflow.com/questions/25571882/pandas-columns-correlation-with-statistical-significance
p = t2.applymap(lambda x: ''.join(['*' for t in [.05, .01, .001] if x<=t]))
t1.round(2).astype(str) + p
t1str = t1.round(2).astype(str) + p
t1str[t1str=="nan"] = "-"
t1str = t1str[[i for i in grade_list if i in h_norm_dfs]]
t1str = t1str.loc[[i for i in grade_list if i in h_norm_dfs]]
## https://stackoverflow.com/questions/55929264/using-a-dataframe-to-format-the-style-of-another-dataframe
t1str_style = t1str.style.format(na_rep='-').set_properties(**{'text-align': 'center'}).applymap_index(lambda v: "font-weight: bold;", axis="index").applymap_index(lambda v: "font-weight: bold;", axis="columns")

t1 = t1[[i for i in grade_list if i in h_norm_dfs]]
t1 = t1.loc[[i for i in grade_list if i in h_norm_dfs]]
styled_result = t1str.style.apply(lambda x: b_g(x,t1,vmin=0,vmax=0.4)).apply(lambda x: font_color(x,t1)).set_properties(**{'text-align': 'center'}).applymap_index(lambda v: "font-weight: bold;", axis="index").applymap_index(lambda v: "font-weight: bold;", axis="columns")
styled_result
# Out:
# {'7th': {'8th': 1.7640748115038327e-10, '9th': 0.0433672773334746, '10th': 1.7640748115038327e-10, '11th': 1.7640748115038327e-10, '12th': 1.7640748115038327e-10}, '8th': {'7th': 0.0146330671949283, '9th': 0.0653940286237804, '10th': 0.0043420798864322, '11th': 2.21965719691007e-10, '12th': 2.21965719691007e-10}, '9th': {'7th': 0.0957045373178224, '8th': 0.0441803504424266, '10th': 0.0148044854998004, '11th': 0.0121922908926148, '12th': 0.0113644098798525}, '10th': {'7th': 6.217364450996021e-10, '8th': 6.217364450996021e-10, '9th': 6.217364450996021e-10, '11th': 0.1474189216129636, '12th': 0.1174349858125715}, '11th': {'7th': 6.426115327110866e-10, '8th': 6.426115327110866e-10, '9th': 0.0133122202653665, '10th': 0.1703057412945039, '12th': 0.2245671167396079}, '12th': {'7th': 4.922840595587987e-10, '8th': 4.922840595587987e-10, '9th': 4.922840595587987e-10, '10th': 0.0636326985202053, '11th': 0.1470399292139637}}
# C:\Users\csh_samu\AppData\Local\Temp\ipykernel_8\1550239438.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
# C:\Users\csh_samu\AppData\Local\Temp\ipykernel_8\1550239438.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c2 = ["#ffffff" if colors.rgb_to_hsv(x[:-1])[-1]<0.7 else "#000000" for x in plt.cm.get_cmap(cmap)(normed) ]
# <style type="text/css">
# #T_1f77c_row0_col0, #T_1f77c_row1_col1, #T_1f77c_row2_col2, #T_1f77c_row3_col3, #T_1f77c_row4_col4, #T_1f77c_row5_col5 {
#   background-color: #000000;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row0_col1, #T_1f77c_row0_col3, #T_1f77c_row0_col4, #T_1f77c_row0_col5, #T_1f77c_row1_col4, #T_1f77c_row1_col5, #T_1f77c_row3_col0, #T_1f77c_row3_col1, #T_1f77c_row3_col2, #T_1f77c_row4_col0, #T_1f77c_row4_col1, #T_1f77c_row5_col0, #T_1f77c_row5_col1, #T_1f77c_row5_col2 {
#   background-color: #440154;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row0_col2 {
#   background-color: #482677;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row1_col0, #T_1f77c_row2_col3 {
#   background-color: #470e61;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row1_col2 {
#   background-color: #453882;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row1_col3 {
#   background-color: #450457;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row2_col0 {
#   background-color: #3c4f8a;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row2_col1 {
#   background-color: #482878;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row2_col4, #T_1f77c_row2_col5 {
#   background-color: #460b5e;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row3_col4, #T_1f77c_row5_col4 {
#   background-color: #2d718e;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row3_col5 {
#   background-color: #355e8d;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row4_col2 {
#   background-color: #470d60;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row4_col3 {
#   background-color: #277e8e;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row4_col5 {
#   background-color: #1f9f88;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_row5_col3 {
#   background-color: #453781;
#   color: #ffffff;
#   text-align: center;
# }
# #T_1f77c_level0_row0, #T_1f77c_level0_row1, #T_1f77c_level0_row2, #T_1f77c_level0_row3, #T_1f77c_level0_row4, #T_1f77c_level0_row5 {
#   font-weight: bold;
# }
# #T_1f77c_level0_col0, #T_1f77c_level0_col1, #T_1f77c_level0_col2, #T_1f77c_level0_col3, #T_1f77c_level0_col4, #T_1f77c_level0_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_1f77c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f77c_level0_col0" class="col_heading level0 col0" >7th</th>
#       <th id="T_1f77c_level0_col1" class="col_heading level0 col1" >8th</th>
#       <th id="T_1f77c_level0_col2" class="col_heading level0 col2" >9th</th>
#       <th id="T_1f77c_level0_col3" class="col_heading level0 col3" >10th</th>
#       <th id="T_1f77c_level0_col4" class="col_heading level0 col4" >11th</th>
#       <th id="T_1f77c_level0_col5" class="col_heading level0 col5" >12th</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f77c_level0_row0" class="row_heading level0 row0" >7th</th>
#       <td id="T_1f77c_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_1f77c_row0_col1" class="data row0 col1" >0.0***</td>
#       <td id="T_1f77c_row0_col2" class="data row0 col2" >0.04***</td>
#       <td id="T_1f77c_row0_col3" class="data row0 col3" >0.0***</td>
#       <td id="T_1f77c_row0_col4" class="data row0 col4" >0.0***</td>
#       <td id="T_1f77c_row0_col5" class="data row0 col5" >0.0***</td>
#     </tr>
#     <tr>
#       <th id="T_1f77c_level0_row1" class="row_heading level0 row1" >8th</th>
#       <td id="T_1f77c_row1_col0" class="data row1 col0" >0.01***</td>
#       <td id="T_1f77c_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_1f77c_row1_col2" class="data row1 col2" >0.07***</td>
#       <td id="T_1f77c_row1_col3" class="data row1 col3" >0.0***</td>
#       <td id="T_1f77c_row1_col4" class="data row1 col4" >0.0***</td>
#       <td id="T_1f77c_row1_col5" class="data row1 col5" >0.0***</td>
#     </tr>
#     <tr>
#       <th id="T_1f77c_level0_row2" class="row_heading level0 row2" >9th</th>
#       <td id="T_1f77c_row2_col0" class="data row2 col0" >0.1***</td>
#       <td id="T_1f77c_row2_col1" class="data row2 col1" >0.04***</td>
#       <td id="T_1f77c_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_1f77c_row2_col3" class="data row2 col3" >0.01***</td>
#       <td id="T_1f77c_row2_col4" class="data row2 col4" >0.01***</td>
#       <td id="T_1f77c_row2_col5" class="data row2 col5" >0.01***</td>
#     </tr>
#     <tr>
#       <th id="T_1f77c_level0_row3" class="row_heading level0 row3" >10th</th>
#       <td id="T_1f77c_row3_col0" class="data row3 col0" >0.0***</td>
#       <td id="T_1f77c_row3_col1" class="data row3 col1" >0.0***</td>
#       <td id="T_1f77c_row3_col2" class="data row3 col2" >0.0***</td>
#       <td id="T_1f77c_row3_col3" class="data row3 col3" >-</td>
#       <td id="T_1f77c_row3_col4" class="data row3 col4" >0.15***</td>
#       <td id="T_1f77c_row3_col5" class="data row3 col5" >0.12***</td>
#     </tr>
#     <tr>
#       <th id="T_1f77c_level0_row4" class="row_heading level0 row4" >11th</th>
#       <td id="T_1f77c_row4_col0" class="data row4 col0" >0.0***</td>
#       <td id="T_1f77c_row4_col1" class="data row4 col1" >0.0***</td>
#       <td id="T_1f77c_row4_col2" class="data row4 col2" >0.01***</td>
#       <td id="T_1f77c_row4_col3" class="data row4 col3" >0.17***</td>
#       <td id="T_1f77c_row4_col4" class="data row4 col4" >-</td>
#       <td id="T_1f77c_row4_col5" class="data row4 col5" >0.22***</td>
#     </tr>
#     <tr>
#       <th id="T_1f77c_level0_row5" class="row_heading level0 row5" >12th</th>
#       <td id="T_1f77c_row5_col0" class="data row5 col0" >0.0***</td>
#       <td id="T_1f77c_row5_col1" class="data row5 col1" >0.0***</td>
#       <td id="T_1f77c_row5_col2" class="data row5 col2" >0.0***</td>
#       <td id="T_1f77c_row5_col3" class="data row5 col3" >0.06***</td>
#       <td id="T_1f77c_row5_col4" class="data row5 col4" >0.15***</td>
#       <td id="T_1f77c_row5_col5" class="data row5 col5" >-</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Sex

# %%
## Sex
pvals_dfs = {}
h_dfs = {}
h_norm_dfs = {}
for i, gi in enumerate(sex_list):
    for j, gj in enumerate(sex_list):
        if gi == gj:
            continue
        col = "MRQAP_pval1s_h_and_1d-simple_sex_" + gi + "-" + gj
        vals = resutls_df_school[col].values
        assert len(vals)==1
        vals = vals[0]
        if np.isnan(vals):
            if np.isnan(resutls_df_school["MRQAP_pval2s_h_and_1d-simple_sex_" + gj + "-" + gi].values[0]):
                continue
            else:
                print ("We have a problem in", gi,gj)
        if gi not in pvals_dfs:
            pvals_dfs[gi] = {}
            h_norm_dfs[gi] = {}
        pvals_dfs[gi][gj] = vals
        h_norm_dfs[gi][gj] = resutls_df_school["h_norm_and_1d-simple_sex_" + gi + "-" + gj].values[0]
print (h_norm_dfs)
print (pvals_dfs)
t1 = pd.DataFrame.from_dict(h_norm_dfs,orient='index')
t2 = pd.DataFrame.from_dict(pvals_dfs,orient="index")
# t1.style.apply(lambda x: t2.applymap(color_cells), axis=None)
## https://stackoverflow.com/questions/25571882/pandas-columns-correlation-with-statistical-significance
p = t2.applymap(lambda x: ''.join(['*' for t in [.05, .01, .001] if x<=t]))
t1.round(2).astype(str) + p
t1str = t1.round(2).astype(str) + p
t1str[t1str=="nan"] = "-"
t1str = t1str.loc[[i for i in sex_list if i in h_norm_dfs]]
t1str = t1str[[i for i in sex_list if i in h_norm_dfs]]
## https://stackoverflow.com/questions/55929264/using-a-dataframe-to-format-the-style-of-another-dataframe
t1str_style = t1str.style.format(na_rep='-').set_properties(**{'text-align': 'center'}).applymap_index(lambda v: "font-weight: bold;", axis="index").applymap_index(lambda v: "font-weight: bold;", axis="columns")

t1 = t1[[i for i in sex_list if i in h_norm_dfs]]
t1 = t1.loc[[i for i in sex_list if i in h_norm_dfs]]
styled_result = t1str.style.apply(lambda x: b_g(x,t1,vmin=0.4,vmax=1.0)).apply(lambda x: font_color(x,t1,vmin=0.4,vmax=1.0)).set_properties(**{'text-align': 'center'}).applymap_index(lambda v: "font-weight: bold;", axis="index").applymap_index(lambda v: "font-weight: bold;", axis="columns")
styled_result
# Out:
# {'Female': {'Male': 0.5032928141412708}, 'Male': {'Female': 0.6020329003562032}}
# {'Female': {'Male': 0.0}, 'Male': {'Female': 0.0}}
# C:\Users\csh_samu\AppData\Local\Temp\ipykernel_8\1550239438.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
# C:\Users\csh_samu\AppData\Local\Temp\ipykernel_8\1550239438.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c2 = ["#ffffff" if colors.rgb_to_hsv(x[:-1])[-1]<0.7 else "#000000" for x in plt.cm.get_cmap(cmap)(normed) ]
# <style type="text/css">
# #T_f5b3e_row0_col0, #T_f5b3e_row1_col1 {
#   background-color: #000000;
#   color: #ffffff;
#   text-align: center;
# }
# #T_f5b3e_row0_col1 {
#   background-color: #443b84;
#   color: #ffffff;
#   text-align: center;
# }
# #T_f5b3e_row1_col0 {
#   background-color: #30698e;
#   color: #ffffff;
#   text-align: center;
# }
# #T_f5b3e_level0_row0, #T_f5b3e_level0_row1 {
#   font-weight: bold;
# }
# #T_f5b3e_level0_col0, #T_f5b3e_level0_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f5b3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5b3e_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_f5b3e_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5b3e_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_f5b3e_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_f5b3e_row0_col1" class="data row0 col1" >0.5***</td>
#     </tr>
#     <tr>
#       <th id="T_f5b3e_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_f5b3e_row1_col0" class="data row1 col0" >0.6***</td>
#       <td id="T_f5b3e_row1_col1" class="data row1 col1" >-</td>
#     </tr>
#   </tbody>
# </table>
